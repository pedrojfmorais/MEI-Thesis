# %%
# !git clone https://github.com/iurii-m/MorDeephy.git
# Out:
# Cloning into 'MorDeephy'...
# remote: Enumerating objects: 425, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 425 (delta 10), reused 14 (delta 6), pack-reused 398 (from 1)
# Receiving objects: 100% (425/425), 3.74 MiB | 20.14 MiB/s, done.
# Resolving deltas: 100% (194/194), done.

# %%
# !python MorDeephy/face_morphing_benchmark/download_data.py
# Out:
# Start Downloading PICS-Aberdeen
# PICS-Aberdeen is downloaded
# Start Downloading PICS-utrecht
# PICS-utrecht is downloaded
# Start Downloading AR Face Database
# Error while AR Face Database download
# Start Downloading FEI Face Database
# FEI Face Database is downloaded
# Start Downloading Face_Research_Lab_London_Set
# Face_Research_Lab_London_Set is downloaded
# Start Downloading Dataset of Ethnic Facial Images of Ecuadorian People
# Dataset of Ethnic Facial Images of Ecuadorian People is downloaded
# Start Downloading FRLL-Morphs
# FRLL-Morphs dataset is downloaded

# %%
# !pip install unlzw patool
# !python MorDeephy/face_morphing_benchmark/data_extract.py
# Out:
# ...
# Start extracting PICS-Aberdeen
# PICS-Aberdeen is extracted
# Start extracting PICS-utrecht
# PICS-Aberdeen is extracted
# Start extracting FEI Face Database
# FEI Face Database is extracted
# Start extracting Face_Research_Lab_London_Set
# Face_Research_Lab_London_Set is extracted
# Start extracting Dataset of Ethnic Facial Images of Ecuadorian People
# INFO patool: Extracting ./data_extracted//EFIEP/Afro-ecuadorians.rar ...
# INFO patool: running /usr/bin/unrar x -kb -or -- /content/data_extracted/EFIEP/Afro-ecuadorians.rar
# INFO patool: ... ./data_extracted//EFIEP/Afro-ecuadorians.rar extracted to `./data_extracted//EFIEP/'.
# Error while Dataset of Ethnic Facial Images of Ecuadorian People extracting
# Start extracting MIT-CBCL
# Error while MIT-CBCL extracting
# Start extracting FRGC-Morphs
# Error while FRGC-Morphs extracting
# Start extracting FERET-Morphs
# Error while FERET-Morphs extracting
# Start extracting Dustone_Morphs dataset
# ...

# %%
# !python MorDeephy/align_protocol_insf.py -n protocol_sd_real -f dataset.txt -s data_extracted/ -d data_aligned/protocol_sd_real -b MorDeephy/face_morphing_benchmark/benchmark_protocols/
# Out:
# 2025-03-31 18:33:21.558884: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743446001.628377   12495 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743446001.650820   12495 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-31 18:33:21.710365: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python MorDeephy/sd_demo_extracting_predictions.py -m protocol_sd_real -n protocol_sd_real -d data_aligned/protocol_sd_real/insf -b MorDeephy/face_morphing_benchmark/benchmark_protocols/ -p models
# Out:
# data_aligned/protocol_sd_real/insf//FRLL-Morphs/facelab_london/morph_amsl/001_002.jpg 0
# data_aligned/protocol_sd_real/insf//FRLL-Morphs/facelab_london/morph_amsl/001_007.jpg 0
# data_aligned/protocol_sd_real/insf//FRLL-Morphs/facelab_london/morph_amsl/001_009.jpg 0
# data_aligned/protocol_sd_real/insf//FRLL-Morphs/facelab_london/morph_amsl/001_010.jpg 0
# data_aligned/protocol_sd_real/insf//FRLL-Morphs/facelab_london/morph_amsl/001_011.jpg 0
# data_aligned/protocol_sd_real/insf//FRLL-Morphs/facelab_london/morph_amsl/001_013.jpg 0
# data_aligned/protocol_sd_real/insf//FRLL-Morphs/facelab_london/morph_amsl/001_014.jpg 0
# data_aligned/protocol_sd_real/insf//FRLL-Morphs/facelab_london/morph_amsl/001_016.jpg 0
# data_aligned/protocol_sd_real/insf//FRLL-Morphs/facelab_london/morph_amsl/001_019.jpg 0
# data_aligned/protocol_sd_real/insf//FRLL-Morphs/facelab_london/morph_amsl/001_020.jpg 0
# data_aligned/protocol_sd_real/insf//FRLL-Morphs/facelab_london/morph_amsl/001_027.jpg 0
# ...

# %%
# !python MorDeephy/sd_benchmark_model.py -m protocol_sd_real -n protocol_sd_real -p models
# Out:
# AUC ROC -  0.94896
# [0.2, 0.1, 0.01, 0.001, 0.0001]
# [np.float64(0.06922592825676521), np.float64(0.14977973568281944), np.float64(0.5959723096286973), np.float64(1.0), np.float64(1.0)]
# EER -  0.1210
# APCER @ values [0.2, 0.1, 0.01, 0.001, 0.0001]
# BPCER values [np.float64(0.06922592825676527), np.float64(0.1485210824417873), np.float64(0.5645059786028949), np.float64(0.9005663939584645), np.float64(0.9005663939584645)]
